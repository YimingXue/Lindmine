# %%
import scipy.io as sio
import matplotlib.pyplot as plt

# %%
loss

# %%
loss = sio.loadmat('/home/xueyiming/TEST/snapshots/patch_size27/ResNetv2_FocalLoss_2019-03-11_21-43-17/ResNetv2_FocalLoss.mat')['loss'][0]
loss_focalloss = sio.loadmat('/home/xueyiming/TEST/snapshots/patch_size27/ResNetv2_FocalLoss_2019-03-11_21-43-17/ResNetv2_FocalLoss.mat')['loss'][0]

# %%
x = [i for i in range(1250)]
plt.xlim(-1, 150) # 限定横轴范围
# plt.ylim(-1, 100) # 限定纵轴范围
plt.plot(x, loss_focalloss, marker='o', mec='r', mfc='w')
# plt.legend() # 让图例生效
plt.xlabel("X label") # X轴标签
plt.ylabel("Y label") # Y轴标签
plt.title("A simple plot") # 标题
# Out:
# Text(0.5, 1.0, 'A simple plot')
